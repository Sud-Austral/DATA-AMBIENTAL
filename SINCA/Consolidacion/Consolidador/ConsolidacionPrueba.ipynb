# %%
#Autor: Ian M.

import numpy as np
import pandas as pd
import os
import pathlib
from os import listdir
from os.path import isfile, join

# %%
#Lectura de nombres de archivos

directorio = 'C:/Users/Ian/Documents/GitHub/DATA-AMBIENTAL/SINCA/Consol/'
contenido = os.listdir(directorio)
registros = []
for fichero in contenido:
    if os.path.isfile(os.path.join(directorio, fichero)) and fichero.endswith('.txt'):
        registros.append(fichero)
print(registros)
# Out:
# ['VIII_estacion_21_de_mayo_mp10.txt', 'VIII_estacion_21_de_mayo_mp2.5.txt', 'VIII_estacion_alabozo_so2.txt', 'VIII_estacion_Balneario_Curanilahue_mp10_diario.txt', 'VIII_estacion_Balneario_Curanilahue_mp2.5.txt', 'VIII_estacion_Balneario_Curanilahue_so2.txt', 'VIII_estacion_Bocatoma_mp10.txt', 'VIII_estacion_Bocatoma_mp2.5.txt', 'VIII_estacion_Bocatoma_so2.txt', 'VIII_estacion_Cayumanqui_so2.txt', 'VIII_estacion_Cerro_Merquin_mp10.txt', 'VIII_estacion_Cerro_Merquin_mp2.5.txt', 'VIII_estacion_Cerro_Merquin_so2.txt', 'VIII_estacion_CESFAM_Los_Angeles_mp10.txt', 'VIII_estacion_Club_de_Empleados_co.txt', 'VIII_estacion_Club_de_Empleados_mp10.txt', 'VIII_estacion_Club_de_Empleados_mp2.5.txt', 'VIII_estacion_Club_de_Empleados_no.txt', 'VIII_estacion_Club_de_Empleados_no2.txt', 'VIII_estacion_Club_de_Empleados_o3.txt', 'VIII_estacion_Club_de_Empleados_so2.txt', 'VIII_estacion_Colicheu _ch4.txt', 'VIII_estacion_Colicheu _chnm.txt', 'VIII_estacion_Colicheu _co.txt', 'VIII_estacion_Colicheu _hct.txt', 'VIII_estacion_Colicheu _mp10.txt', 'VIII_estacion_Colicheu _no.txt', 'VIII_estacion_Colicheu _no2.txt', 'VIII_estacion_Colicheu _nox.txt', 'VIII_estacion_Colicheu _o3.txt', 'VIII_estacion_Colicheu _so2.txt', 'VIII_estacion_Consultorio_San_Vicente_mp10.txt', 'VIII_estacion_Consultorio_San_Vicente_mp2.5.txt', 'VIII_estacion_Consultorio_San_Vicente_no.txt', 'VIII_estacion_Consultorio_San_Vicente_no2.txt', 'VIII_estacion_Consultorio_San_Vicente_nox.txt', 'VIII_estacion_Consultorio_San_Vicente_so2.txt', 'VIII_estacion_Coronel_Norte_co.txt', 'VIII_estacion_Coronel_Norte_mp10.txt', 'VIII_estacion_Coronel_Norte_mp2.5.txt', 'VIII_estacion_Coronel_Norte_no.txt', 'VIII_estacion_Coronel_Norte_no2.txt', 'VIII_estacion_Coronel_Norte_nox.txt', 'VIII_estacion_Coronel_Sur_ch4.txt', 'VIII_estacion_Coronel_Sur_chnm.txt', 'VIII_estacion_Coronel_Sur_co.txt', 'VIII_estacion_Coronel_Sur_hct.txt', 'VIII_estacion_Coronel_Sur_mp10.txt', 'VIII_estacion_Coronel_Sur_no.txt', 'VIII_estacion_Coronel_Sur_no2.txt', 'VIII_estacion_Coronel_Sur_nox.txt', 'VIII_estacion_Coronel_Sur_o3.txt', 'VIII_estacion_Coronel_Sur_so2.txt', 'VIII_estacion_ENAP_Price_co.txt', 'VIII_estacion_ENAP_Price_mp10.txt', 'VIII_estacion_ENAP_Price_mp2.5.txt', 'VIII_estacion_ENAP_Price_no2.txt', 'VIII_estacion_ENAP_Price_o3.txt', 'VIII_estacion_ENAP_Price_so2.txt', 'VIII_estacion_entre_rios_mp10.txt', 'VIII_estacion_Escuadron_ENEL_co.txt', 'VIII_estacion_Escuadron_ENEL_mp10.txt', 'VIII_estacion_Escuadron_ENEL_mp2.5.txt', 'VIII_estacion_Escuadron_ENEL_no.txt', 'VIII_estacion_Escuadron_ENEL_o3.txt', 'VIII_estacion_Escuadron_ENEL_so2.txt', 'VIII_estacion_Escuadron_ENESA_mp10.txt', 'VIII_estacion_Hualqui_mp10.txt', 'VIII_estacion_Hualqui_mp2.5.txt', 'VIII_estacion_Hualqui_no.txt', 'VIII_estacion_Hualqui_no2.txt', 'VIII_estacion_Hualqui_nox.txt', 'VIII_estacion_Hualqui_o3.txt', 'VIII_estacion_Hualqui_so2.txt', 'VIII_estacion_Indura_co.txt', 'VIII_estacion_Indura_mp10.txt', 'VIII_estacion_Indura_mp2.5.txt', 'VIII_estacion_Indura_no2.txt', 'VIII_estacion_Indura_o3.txt', 'VIII_estacion_Indura_so2.txt', 'VIII_estacion_INIA_Chillan_co.txt', 'VIII_estacion_INIA_Chillan_mp10.txt', 'VIII_estacion_INIA_Chillan_mp2.5.txt', 'VIII_estacion_Inpesca_mp10.txt', 'VIII_estacion_Inpesca_mp2.5.txt', 'VIII_estacion_Inpesca_so2.txt', 'VIII_estacion_JUNJI_mp10.txt', 'VIII_estacion_JUNJI_mp2.5.txt', 'VIII_estacion_JUNJI_no2.txt', 'VIII_estacion_JUNJI_o3.txt', 'VIII_estacion_JUNJI_so2.txt', 'VIII_estacion_Kingston_College_co.txt', 'VIII_estacion_Kingston_College_mp10.txt', 'VIII_estacion_Kingston_College_mp2.5.txt', 'VIII_estacion_Kingston_College_no.txt', 'VIII_estacion_Kingston_College_no2.txt', 'VIII_estacion_Kingston_College_nox.txt', 'VIII_estacion_Kingston_College_o3.txt', 'VIII_estacion_Kingston_College_so2.txt', 'VIII_estacion_laja_co.txt', 'VIII_estacion_laja_mp10.txt', 'VIII_estacion_laja_mp2.5.txt', 'VIII_estacion_laja_no.txt', 'VIII_estacion_laja_no2.txt', 'VIII_estacion_laja_o3.txt', 'VIII_estacion_laja_so2.txt', 'V ...

# %%
#Unión de Tablas

salida = []
for i in registros:
    dfaux = pd.read_csv(i, sep=" ")
    salida.append(dfaux.copy())
    #merged_df = df.append(df)
    #print(merged_df)
dfsalida = pd.concat(salida)
dfsalida
# Out:
#        FECHA..YYMMDD.  HORA..HHMM.  Registros.validados  \
# 1              120414          100                  NaN
# 2              120414          200                  NaN
# 3              120414          300                  NaN
# 4              120414          400                  NaN
# 5              120414          500                  NaN
# ...               ...          ...                  ...
# 35299          130823         1900                  NaN
# 35300          130823         2000                  NaN
# 35301          130823         2100                  NaN
# 35302          130823         2200                  NaN
# 35303          130823         2300                  NaN
#
#        Registros.preliminares  Registros.no.validados   X  \
# 1                       22.33                     NaN NaN
# 2                       20.30                     NaN NaN
# 3                       23.01                     NaN NaN
# 4                       25.72                     NaN NaN
# 5                       25.05                     NaN NaN
# ...                       ...                     ...  ..
# 35299                     NaN                     NaN NaN
# 35300                     NaN                     NaN NaN
# 35301                     NaN                     NaN NaN
# 35302                     NaN                     NaN NaN
# 35303                     NaN                     NaN NaN
#
#              identificador1 identificador2
# 1                21_de_mayo           mp10
# 2                21_de_mayo           mp10
# 3                21_de_mayo           mp10
# 4                21_de_mayo           mp10
# 5                21_de_mayo           mp10
# ...                     ...            ...
# 35299  San_Vicente_Bomberos            so2
# 35300  San_Vicente_Bomberos            so2
# 35301  San_Vicente_Bomberos            so2
# 35302  San_Vicente_Bomberos            so2
# 35303  San_Vicente_Bomberos            so2
#
# [9958227 rows x 8 columns]

# %%
#Grabado de la tabla unida a csv

dfsalida.to_csv("Consolidado_VIII_Biobio.txt",index=False)

# %%
#Conversor archivos a .csv

for i in registros:
    df = pd.read_csv(i, sep=" ")
    name = i.rstrip(i[-4:])
    df.to_csv(name+".csv",index=False)

# %%
#Grabado de la tabla unida a csv

dfsalida.to_csv("Consolidado_Antofagasta.txt",index=False)

# %%
filename = i
name = filename.rstrip(filename[-4:])
print(name)
# Out:
# I_estacion_alto_hospicio_mp2.5

# %%
df1 = pd.read_csv(registros[0], sep=" ")
df2 = pd.read_csv(registros[1], sep=" ")

df3 = df1.append(df1)
print(merged_df)
# Out:
#        FECHA..YYMMDD.  HORA..HHMM.  Registros.validados  \
# 1              130601          100                 85.0
# 2              130601          200                 58.0
# 3              130601          300                 52.0
# 4              130601          400                 48.0
# 5              130601          500                 75.0
# ...               ...          ...                  ...
# 69499          210505         1900                  NaN
# 69500          210505         2000                  NaN
# 69501          210505         2100                  NaN
# 69502          210505         2200                  NaN
# 69503          210505         2300                  NaN
#
#        Registros.preliminares  Registros.no.validados   X identificador1  \
# 1                         NaN                     NaN NaN    antofagasta
# 2                         NaN                     NaN NaN    antofagasta
# 3                         NaN                     NaN NaN    antofagasta
# 4                         NaN                     NaN NaN    antofagasta
# 5                         NaN                     NaN NaN    antofagasta
# ...                       ...                     ...  ..            ...
# 69499                     8.0                     NaN NaN    antofagasta
# 69500                    12.0                     NaN NaN    antofagasta
# 69501                    27.0                     NaN NaN    antofagasta
# 69502                    10.0                     NaN NaN    antofagasta
# 69503                    11.0                     NaN NaN    antofagasta
#
#       identificador2
# 1               mp10
# 2               mp10
# 3               mp10
# 4               mp10
# 5               mp10
# ...              ...
# 69499          mp2.5
# 69500          mp2.5
# 69501          mp2.5
# 69502          mp2.5
# 69503          mp2.5
#
# [139006 rows x 8 columns]
